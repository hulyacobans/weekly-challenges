# %% [markdown]
# # **1. SERP API**

# %%
import pandas as pd
import json
import requests

# %%
import requests

# set up the request parameters
params = {
  'api_key': 'Your API KEY',
  'q': 'python for seo', #search query
  'device': 'mobile',
  'gl': 'us',
  'hl': 'en',
  'google_domain': 'google.com'
}

# make the http GET request to Scale SERP
api_result = requests.get('https://api.scaleserp.com/search', params).text #Your SERP API get URL might be different. You should check it.
a = json.loads(api_result)


df = pd.DataFrame(a['organic_results'])
df

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Harvest API**

# %%
#https://help.getharvest.com/api-v2/

headers = {
    'Harvest-Account-ID': 'YOUR ID',
    'Authorization': 'Your Authorization',
    'User-Agent': 'Harvest API Example',
}

response = requests.get('https://api.harvestapp.com/v2/reports/time/tasks?from=20200301&to=20200331', headers=headers).text
a = json.loads(response)

print(a['results'])

# %% [markdown]
# ![102.png](data:image/png;base64,...)
